# %%
print("Hello 1")
# Out:
# Hello 1

# %%
print("Hello 2")
# Out:
# Hello 2

# %%
import numpy as np
print(np.array([1, 2, 3]))
# Out:
# [1 2 3]

# %%
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("hell World")

# %%
i = 54

# %%
i

# %%
import sklearn
