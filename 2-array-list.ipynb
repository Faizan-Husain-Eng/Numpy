# %% [markdown]
# #array creation:Conversion from other Python structures

# %%
import numpy as np

# %%
listarray = np.array([[1, 2, 3], [5, 8, 5], [0, 3, 1]])

# %%
listarray
# Out:
# array([[1, 2, 3],
#        [5, 8, 5],
#        [0, 3, 1]])

# %%
listarray.dtype
# Out:
# dtype('int64')

# %%
listarray.shape
# Out:
# (3, 3)

# %%
listarray.size
# Out:
# 9
