# %%
import numpy as np

# %%
one = np.array([1, 2, 3, 4, 5, 786 ,7])

# %%
one.argmax()
# Out:
# np.int64(5)

# %%
one.argmin()
# Out:
# np.int64(0)

# %%
one.argsort()
# Out:
# array([0, 1, 2, 3, 4, 6, 5])
