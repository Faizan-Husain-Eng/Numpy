# %% [markdown]
# #Welcome to the array numpy

# %%
import numpy as np

# %%
myarr = np.array([[3, 6, 36, 7]], np.int8)

# %%
myarr[0,1]
# Out:
# np.int8(6)

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int8')

# %%
myarr[0,1]
# Out:
# np.int8(6)

# %%
myarr[0, 1] = 45

# %%
myarr
# Out:
# array([[ 3, 45, 36,  7]], dtype=int8)
